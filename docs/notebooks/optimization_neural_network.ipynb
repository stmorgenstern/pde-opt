# %% [markdown]
# # PDE-constrained optimization with neural network chemical potential

# %% [markdown]
# In this notebook, we show how to use the PDEModel class to perform PDE-constrained optimization with a neural network parameterization.
#
# We will use a neural network to represent the non-gradient part of the chemical potential.

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

import pde_opt
from pde_opt.pde_model import PDEModel
from pde_opt.numerics.equations.cahn_hilliard import CahnHilliard2DPeriodic
from pde_opt.numerics.solvers import SemiImplicitFourierSpectral
from pde_opt.numerics.solvers import ROCK2JAX
from pde_opt.numerics.domains import Domain
from pde_opt.numerics.functions.cnn import PeriodicCNN

import equinox as eqx

# %% [markdown]
# We will first create the domain for the PDE. We choose to use a small domain so the code runs in a reasonable amount of time in the notebook.

# %%
Nx = Ny = 32
Lx = Ly = 0.01 * Nx

domain = Domain(
    (Nx, Ny),
    (
        (-Lx / 2, Lx / 2),
        (-Ly / 2, Ly / 2),
    ),
    "dimensionless",
)

# %% [markdown]
# Constructing the PDE model for optimization just involves specifying the equation, domain, and time stepping method.

# %%
opt_model = PDEModel(
    equation_type=CahnHilliard2DPeriodic,
    domain=domain,
    # solver_type=SemiImplicitFourierSpectral,
    solver_type=ROCK2JAX,
)

# %% [markdown]
# Here, we set parameter values for the terms in the Cahn-Hilliard equation. These parameters will serve as our "ground truth", which we will try to recover in our optimization. In this example, we only focus on learning the chemical potential.

# %%
params = {"kappa": 0.002, "mu": lambda c: jnp.log(c / (1.0 - c)) + 3.0 * (1.0 - 2.0 * c), "D": lambda c: jnp.ones_like(c)}

# solver_params = {"A": 0.5}
solver_params = {}

# %% [markdown]
# Now we can solve the system with the parameters to get the training dataset we will use in the optimization.

# %%
key = jax.random.PRNGKey(0)
y0 = jnp.clip(0.01 * jax.random.normal(key, (Nx, Ny)) + 0.5, 0.0, 1.0)
ts = jnp.linspace(0.0, 0.02, 100)
sol = opt_model.solve(params, y0, ts, solver_params, dt0=0.000001, max_steps=1000000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 y0 = jnp.clip(0.01 * jax.random.normal(key, (Nx, Ny)) + 0.5, 0.0, 1.0)
#       3 ts = jnp.linspace(0.0, 0.02, 100)
# ----> 4 sol = opt_model.solve(params, y0, ts, solver_params, dt0=0.000001, max_steps=1000000)
#
# File /orcd/home/002/stm16109/research/pde-opt/pde_opt/pde_model.py:117, in PDEModel.solve(self, parameters, y0, ts, solver_parameters, adjoint, dt0, max_steps, stepsize_controller)
#     112 full_solver_params = prepare_solver_params(
#     113     self.solver_type, solver_parameters, equation
#     114 )
#     116 # Initialize the solver with solver_parameters and equation attributes
# --> 117 solver = self.solver_type(**full_solver_params)
#     119 # Solve with diffrax
#     120 solution = dfx.diffeqsolve(
#     121     dfx.ODETerm(
#     122         jax.jit(lambda t, y, args: equation.rhs(y, t))
#    (...)
#     133     stepsize_controller=stepsize_controller,
#     134 )
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/pde-opt-env/lib/python3.10/site-packages/equinox/_module/_better_abstract.py:232, in BetterABCMeta.__call__(cls, *args, **kwargs)
#     227     abstract_class_vars = set(cls.__abstractclassvars__)  # pyright: ignore
#     228     raise TypeError(
#     229         f"Can't instantiate abstract class {cls.__name__} with abstract class "
#     230         f"attributes {abstract_class_vars}"
#     231     )
# --> 232 self = super().__call__(*args, **kwargs)
#     233 if len(cls.__abstractvars__) > 0:  # pyright: ignore
#     234     abstract_class_vars = set(cls.__abstractvars__)  # pyright: ignore
#
# TypeError: SemiImplicitFourierSpectral.__init__() missing 1 required positional argument: 'A'

# %% [markdown]
# We can visualize what this solution looks like.

# %%
fig, ax = plt.subplots(1, 5)
ax[0].imshow(sol[0], vmin=0.0, vmax=1.0)
ax[0].set_title(f"t = {ts[0]:.3f}")
ax[1].imshow(sol[10], vmin=0.0, vmax=1.0)
ax[1].set_title(f"t = {ts[10]:.3f}")
ax[2].imshow(sol[20], vmin=0.0, vmax=1.0)
ax[2].set_title(f"t = {ts[20]:.3f}")
ax[3].imshow(sol[50], vmin=0.0, vmax=1.0)
ax[3].set_title(f"t = {ts[50]:.3f}")
ax[4].imshow(sol[-1], vmin=0.0, vmax=1.0)
ax[4].set_title(f"t = {ts[-1]:.3f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# We will use a CNN to represent the non-gradient part of the chemical potential term in the Cahn-Hilliard equation.
#
# This CNN is set up with circular padding to properly account for the periodic boundary conditions of the simulation. It also uses same padding to return an array of the same shape as the input. With a stride of 1, it is perfectly translationally equivariant (since the padding is circular, it is specifically translationally equivariant on a torus).

# %%
model = PeriodicCNN(
    in_channels=1,
    hidden_channels=(32, 64, 64),
    out_channels=1,
    kernel_size=3,
    key=jax.random.PRNGKey(0),
)

model = eqx.filter_jit(model)

# %% [markdown]
# The train function expects the data is passed in as a dictionary with the time points specified in the 'ts' key and the fields specified in the 'ys' key.
#
# We must also pass in a list of lists indicating which indices we want to include in the simulation. Each inner list has the following format: [starting time, time to evaluate loss, time to evaluate loss, ...., final time to evaluate loss]. When computing the total loss, we vmap over each list and average.
#
# You can also experiment with adding noise to the data. For this example, we don't add noise to speed up the optimization process, but the method is robust to certain levels of noise.

# %%
data = {}
data['ys'] = sol
data['ts'] = ts

inds = [[30,40,50], [50,60,70], [70,80,90]]

# %% [markdown]
# Now we need an initial set of parameters at which to start the optimization at. For the chemical potential, our initial parameters are the CNN model we defined above. This is a nice part of using Equinox to create our neural networks, as the whole model is represented as a PyTree, and we can use filtered operations like JIT and grad to properly extract the arrays, or use partition and combine operations to separate the array and non-array leaves. We can therefore pass full equinox models as "parameters" in our equation, which makes the interface much more general and easier to use.
#
# We put the parameters or models we wish to optimize over in a separate dictionary than the parameters that we wish to remain fixed/static. Finally, we can regularize the parameters using a weights dictionary. This dictionary must match the structure of the optimization parameters dictionary, and the PyTrees for each key must have the same structure. Then we can use tree_map and tree_reduce to compute the regularization term. The lambda_reg is then a global scale factor applied to every regularization term.

# %%
init_params = {
    "mu": model,
}

static_params = {
    "kappa": 0.002,
    "D": lambda c: jnp.ones_like(c),
}

# solver_parameters = {
#     "A": 0.5,
# }
solver_parameters = {}

weights = {
    "mu": None
}

lambda_reg = 0.0

# %% [markdown]
# Let's now visualize what the initial solution looks like for our starting guess of chemical potential. Note that there is no phase separation!

# %%
test_sol = opt_model.solve({**init_params, **static_params}, y0, ts, solver_parameters, dt0=0.000001, max_steps=1000000)

fig, ax = plt.subplots(1, 5)
ax[0].imshow(test_sol[0], vmin=0.0, vmax=1.0)
ax[1].imshow(test_sol[10], vmin=0.0, vmax=1.0)
ax[2].imshow(test_sol[20], vmin=0.0, vmax=1.0)
ax[3].imshow(test_sol[50], vmin=0.0, vmax=1.0)
ax[4].imshow(test_sol[-1], vmin=0.0, vmax=1.0)
plt.tight_layout()
plt.show()

# %% [markdown]
# We can now pass in the dataset, the optimization indices, the parameters we want to fit, the static parameters, and the regularization weights into the train function. This should take around 4 minutes per 100 steps and the results will be improved for more steps.

# %%
res = opt_model.train(data, inds, init_params, static_params, solver_parameters, weights, lambda_reg, method="mse", max_steps=100)
# Out:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 res = opt_model.train(data, inds, init_params, static_params, solver_parameters, weights, lambda_reg, method="mse", max_steps=100)
#
# File /orcd/home/002/stm16109/research/pde-opt/pde_opt/pde_model.py:449, in PDEModel.train(self, data, inds, opt_parameters, other_parameters, solver_parameters, weights, lambda_reg, method, max_steps)
#     433     return self.mse(
#     434         {**full_params, **other_parameters},
#     435         args,
#    (...)
#     440         adjoint=dfx.RecursiveCheckpointAdjoint(),
#     441     )
#     443 solver = optx.BFGS(
#     444     rtol=1e-8,
#     445     atol=1e-8,
#     446     verbose=frozenset({"step", "accepted", "loss", "step_size"}),
#     447 )
# --> 449 sol = optx.minimise(
#     450     mse_wrapper,
#     451     solver,
#     452     opt_params,
#     453     args=(y0s, values),
#     454     max_steps=max_steps,
#     455     throw=False,
#     456 )
#     458 res = eqx.combine(sol.value, opt_params_static)
#     460 return {**res, **other_parameters}
#
#     [... skipping hidden 7 frame]
#
# File ~/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1297, in ExecuteReplicated.__call__(self, *args)
#    1294 if (self.ordered_effects or self.has_unordered_effects
#    1295     or self.has_host_callbacks):
#    1296   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1297   results = self.xla_executable.execute_sharded(
#    1298       input_bufs, with_tokens=True
#    1299   )
#    1301   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1302       len(self.ordered_effects))
#    1303   sharded_runtime_token = results.consume_token()
#
# XlaRuntimeError: INTERNAL: CpuCallback error calling callback: Traceback (most recent call last):
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/runpy.py", line 86, in _run_code
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/asyncio/events.py", line 80, in _run
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#   File "/tmp/ipykernel_3775410/162905030.py", line 1, in <module>
#   File "/orcd/home/002/stm16109/research/pde-opt/pde_opt/pde_model.py", line 449, in train
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/equinox/_jit.py", line 209, in __call__
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/equinox/_jit.py", line 263, in _call
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/traceback_util.py", line 182, in reraise_with_filtered_traceback
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/pjit.py", line 292, in cache_miss
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/pjit.py", line 153, in _python_pjit_helper
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/pjit.py", line 1877, in _pjit_call_impl_python
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/profiler.py", line 354, in wrapper
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py", line 1297, in __call__
#   File "/home/stm16109/.conda/envs/pde-opt-env/lib/python3.10/site-packages/jax/_src/callback.py", line 781, in _wrapped_callback
# KeyboardInterrupt:

# %% [markdown]
# Finally, we can see that our learned chemical potential matches the ground truth chemical potential.

# %%
cs = jnp.linspace(0.01, 0.99, 100)

c_gt = params['mu'](cs)

c_nn_init = []
c_nn = []
for c in cs:
    c_nn_init.append(jnp.mean(init_params['mu'](c * jnp.ones_like(y0))))
    c_nn.append(jnp.mean(res['mu'](c * jnp.ones_like(y0))))

# Shift c_nn to make value at c=0.5 zero
c_nn_array = jnp.array(c_nn)
c_nn_init_array = jnp.array(c_nn_init)
idx_05 = jnp.argmin(jnp.abs(cs - 0.5))  # Find index closest to c=0.5
shift = c_nn_array[idx_05]
shift_init = c_nn_init_array[idx_05]
c_nn = c_nn_array - shift
c_nn_init = c_nn_init_array - shift_init


fig, ax = plt.subplots(1, 1)
ax.plot(cs, c_gt, label='G.T.')
ax.plot(cs, c_nn_init, label='Initial')
ax.plot(cs, c_nn, label='Learned')
ax.set_xlabel('c')
ax.set_ylabel('mu')
ax.legend()
plt.show()

# %% [markdown]
# And we can use this chemical potential to simulate the full PDE and compare with the ground truth simulation.

# %%
opt_sol = opt_model.solve(res, y0, ts, solver_parameters, dt0=0.000001, max_steps=1000000)

fig, ax = plt.subplots(2, 5)
ax[0,0].imshow(sol[0], vmin=0.0, vmax=1.0)
ax[0,0].set_ylabel("Ground Truth")
ax[0,0].set_title(f"t = {ts[0]:.3f}")
ax[0,1].imshow(sol[10], vmin=0.0, vmax=1.0)
ax[0,1].set_title(f"t = {ts[10]:.3f}")
ax[0,2].imshow(sol[20], vmin=0.0, vmax=1.0)
ax[0,2].set_title(f"t = {ts[20]:.3f}")
ax[0,3].imshow(sol[50], vmin=0.0, vmax=1.0)
ax[0,3].set_title(f"t = {ts[50]:.3f}")
ax[0,4].imshow(sol[-1], vmin=0.0, vmax=1.0)
ax[0,4].set_title(f"t = {ts[-1]:.3f}")
ax[1,0].imshow(opt_sol[0], vmin=0.0, vmax=1.0)
ax[1,0].set_ylabel("Learned")
ax[1,1].imshow(opt_sol[10], vmin=0.0, vmax=1.0)
ax[1,2].imshow(opt_sol[20], vmin=0.0, vmax=1.0)
ax[1,3].imshow(opt_sol[50], vmin=0.0, vmax=1.0)
ax[1,4].imshow(opt_sol[-1], vmin=0.0, vmax=1.0)
plt.tight_layout()
plt.show()
